# %% [markdown]
# <a href="https://colab.research.google.com/github/tiyash-dutta24-git/Tiyash-LS-ML-assignments/blob/main/You_Only_Look_Once.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: unzip the zipped train, test and valid datasets

# !unzip /content/train-20240711T161612Z-001.zip
# !unzip /content/test-20240711T161609Z-001.zip
# !unzip /content/valid-20240711T161617Z-001.zip

# %%
# prompt: import a pre-trained yolov8 model, use it to train on train data, test on test data and validate on valid data. data.yml file is given - /content/data.yaml. After that generate confusion matrix and result.png, everything correctly.

import ultralytics
model = ultralytics.YOLO('/content/yolov8n-cls.pt')  # load a pretrained YOLOv8x model

# Train the model on the train dataset
# !yolo task=classify mode=train data=/content/data.yaml model=yolov8n-cls.pt epochs=1 imgsz=640

# Test the model on the test dataset
# !yolo task=classify mode=test data=/content/data.yaml model=yolov8n-cls.pt

# Validate the model on the valid dataset
# !yolo task=classify mode=val data=/content/data.yaml model=yolov8n-cls.pt
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
